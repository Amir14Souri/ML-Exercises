# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

# %% [markdown]
# ## reading data

# %%
data = pd.read_table('CaliforniaHousing/cal_housing.data', sep=',')
data
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 0        -122.23     37.88              41.0       880.0          129.0
# 1        -122.22     37.86              21.0      7099.0         1106.0
# 2        -122.24     37.85              52.0      1467.0          190.0
# 3        -122.25     37.85              52.0      1274.0          235.0
# 4        -122.25     37.85              52.0      1627.0          280.0
# ...          ...       ...               ...         ...            ...
# 20635    -121.09     39.48              25.0      1665.0          374.0
# 20636    -121.21     39.49              18.0       697.0          150.0
# 20637    -121.22     39.43              17.0      2254.0          485.0
# 20638    -121.32     39.43              18.0      1860.0          409.0
# 20639    -121.24     39.37              16.0      2785.0          616.0
#
#        population  households  medianIncome  medianHouseValue
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   longitude         20640 non-null  float64
#  1   latitude          20640 non-null  float64
#  2   housingMedianAge  20640 non-null  float64
#  3   totalRooms        20640 non-null  float64
#  4   totalBedrooms     20640 non-null  float64
#  5   population        20640 non-null  float64
#  6   households        20640 non-null  float64
#  7   medianIncome      20640 non-null  float64
#  8   medianHouseValue  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
data.describe()
# Out:
#           longitude      latitude  housingMedianAge    totalRooms  \
# count  20640.000000  20640.000000      20640.000000  20640.000000
# mean    -119.569704     35.631861         28.639486   2635.763081
# std        2.003532      2.135952         12.585558   2181.615252
# min     -124.350000     32.540000          1.000000      2.000000
# 25%     -121.800000     33.930000         18.000000   1447.750000
# 50%     -118.490000     34.260000         29.000000   2127.000000
# 75%     -118.010000     37.710000         37.000000   3148.000000
# max     -114.310000     41.950000         52.000000  39320.000000
#
#        totalBedrooms    population    households  medianIncome  \
# count   20640.000000  20640.000000  20640.000000  20640.000000
# mean      537.898014   1425.476744    499.539680      3.870671
# std       421.247906   1132.462122    382.329753      1.899822
# min         1.000000      3.000000      1.000000      0.499900
# ...

# %%
data.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# ## Train-Test split

# %% [markdown]
# ### purely random

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)

# %%
data['income_category'] = pd.cut(data['medianIncome'], bins=[0., 1.5, 3., 4.5, 6., np.inf],
                                labels=[1, 2, 3, 4, 5])
data['income_category'].hist()
plt.show()

# %% [markdown]
# ### stratified split

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(data, data['income_category']):
    strat_train_set = data.loc[train_index]
    strat_test_set = data.loc[test_index]
strat_train_set
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 12655    -121.46     38.52              29.0      3873.0          797.0
# 15502    -117.23     33.09               7.0      5320.0          855.0
# 2908     -119.04     35.37              44.0      1618.0          310.0
# 14053    -117.13     32.75              24.0      1877.0          519.0
# 20496    -118.70     34.28              27.0      3536.0          646.0
# ...          ...       ...               ...         ...            ...
# 15174    -117.07     33.03              14.0      6665.0         1231.0
# 12661    -121.42     38.51              15.0      7901.0         1422.0
# 19263    -122.72     38.44              48.0       707.0          166.0
# 19140    -122.70     38.31              14.0      3155.0          580.0
# 19773    -122.14     39.97              27.0      1079.0          222.0
#
#        population  households  medianIncome  medianHouseValue income_category
# ...

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop('income_category', axis=1, inplace=True)
strat_train_set
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 12655    -121.46     38.52              29.0      3873.0          797.0
# 15502    -117.23     33.09               7.0      5320.0          855.0
# 2908     -119.04     35.37              44.0      1618.0          310.0
# 14053    -117.13     32.75              24.0      1877.0          519.0
# 20496    -118.70     34.28              27.0      3536.0          646.0
# ...          ...       ...               ...         ...            ...
# 15174    -117.07     33.03              14.0      6665.0         1231.0
# 12661    -121.42     38.51              15.0      7901.0         1422.0
# 19263    -122.72     38.44              48.0       707.0          166.0
# 19140    -122.70     38.31              14.0      3155.0          580.0
# 19773    -122.14     39.97              27.0      1079.0          222.0
#
#        population  households  medianIncome  medianHouseValue
# ...

# %%
data = strat_train_set.copy()
data
# Out:
#        longitude  latitude  housingMedianAge  totalRooms  totalBedrooms  \
# 12655    -121.46     38.52              29.0      3873.0          797.0
# 15502    -117.23     33.09               7.0      5320.0          855.0
# 2908     -119.04     35.37              44.0      1618.0          310.0
# 14053    -117.13     32.75              24.0      1877.0          519.0
# 20496    -118.70     34.28              27.0      3536.0          646.0
# ...          ...       ...               ...         ...            ...
# 15174    -117.07     33.03              14.0      6665.0         1231.0
# 12661    -121.42     38.51              15.0      7901.0         1422.0
# 19263    -122.72     38.44              48.0       707.0          166.0
# 19140    -122.70     38.31              14.0      3155.0          580.0
# 19773    -122.14     39.97              27.0      1079.0          222.0
#
#        population  households  medianIncome  medianHouseValue
# ...

# %% [markdown]
# ## Visualizing data

# %%
data.plot(kind='scatter', x='longitude', y='latitude', alpha=0.1)
plt.show()

# %%
data.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
s=data["population"]/100, label="population", figsize=(10,7),
c="medianHouseValue", cmap=plt.get_cmap("jet"), colorbar=True)
plt.legend()
plt.show()

# %% [markdown]
# ## Correlation check

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
from pandas.plotting import scatter_matrix

# %%
features = ['medianHouseValue', 'medianIncome', 'totalRooms', 'housingMedianAge']
scatter_matrix(data[features], figsize=(12, 8))
plt.show()

# %%
data.plot(kind='scatter', x='medianIncome', y='medianHouseValue', alpha=0.1)
# Out:
# <Axes: xlabel='medianIncome', ylabel='medianHouseValue'>

# %%
data["rooms_per_household"] = data["totalRooms"] / data["households"]
data["bedrooms_per_room"] = data["totalBedrooms"] / data["totalRooms"]
data["population_per_household"] = data["population"] / data["households"]
corr_matrix = data.corr()
plt.subplots(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## First Model - Linear Regression

# %%
X_train = data.drop('medianHouseValue', axis=1)
y_train = data['medianHouseValue']

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
some_data = X_train.iloc[:5]
some_labels = y_train.iloc[:5]
print("Predictions: ", lin_model.predict(some_data))
print("Labels: ", some_labels)
# Out:
# Predictions:  [ 88537.95338101 295955.1139121  168683.6945346  182319.79081301
#  238245.76926702]
# Labels:  12655     72100.0
# 15502    279600.0
# 2908      82700.0
# 14053    112500.0
# 20496    238300.0
# Name: medianHouseValue, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
predict_train = lin_model.predict(X_train)
mse_train = mean_squared_error(y_train, predict_train)
rmse_train = np.sqrt(mse_train)
print("Train set RMSE: ", rmse_train) # underfitted
# Out:
# Train set RMSE:  68809.73788221367

# %% [markdown]
# ## Second Model - Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
tree_model = DecisionTreeRegressor()
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("Predictions: ", tree_model.predict(some_data))
print("Labels: ", some_labels)
# Out:
# Predictions:  [ 72100. 279600.  82700. 112500. 238300.]
# Labels:  12655     72100.0
# 15502    279600.0
# 2908      82700.0
# 14053    112500.0
# 20496    238300.0
# Name: medianHouseValue, dtype: float64

# %%
predict_train = tree_model.predict(X_train)
mse_train = mean_squared_error(y_train, predict_train)
rmse_train = np.sqrt(mse_train)
print("Train set RMSE: ", rmse_train) # overfitted
# Out:
# Train set RMSE:  0.0

# %% [markdown]
# ## Cross-Validation - Decision Tree Regression

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(tree_model, X_train, y_train, scoring="neg_mean_squared_error", cv=10)
rmse_validation = np.sqrt(-scores)

print("Scores: ", scores)
print("Mean: ", scores.mean())
print("Standard Deviation: ", scores.std())
# Out:
# Scores:  [-6.08799693e+09 -5.48952174e+09 -4.73983098e+09 -5.57082980e+09
#  -5.33578669e+09 -6.03188076e+09 -5.37187332e+09 -5.19707614e+09
#  -4.97191768e+09 -5.63549836e+09]
# Mean:  -5443221240.547449
# Standard Deviation:  401467172.8365413

# %% [markdown]
# ## Cross-Validation - Linear Regression

# %%
scores = cross_val_score(lin_model, X_train, y_train, scoring="neg_mean_squared_error", cv=10)
rmse_validation = np.sqrt(-scores)

print("Scores: ", scores)
print("Mean: ", scores.mean())
print("Standard Deviation: ", scores.std())
# Out:
# Scores:  [-5.14044782e+09 -4.15857944e+09 -4.68820605e+09 -4.71275475e+09
#  -4.56544671e+09 -5.28937740e+09 -5.06783335e+09 -4.77732048e+09
#  -4.42765267e+09 -4.97505803e+09]
# Mean:  -4780267671.153527
# Standard Deviation:  328570149.33918446

# %% [markdown]
# ## Third Model - Random Forest Regression (Cross-Validation)

# %%
from sklearn.ensemble import RandomForestRegressor
forest_model = RandomForestRegressor()
forest_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
predict_train = forest_model.predict(X_train)
mse_train = mean_squared_error(y_train, predict_train)
rmse_train = np.sqrt(mse_train)
print("Train set RMSE: ", rmse_train)
# Out:
# Train set RMSE:  18909.306739720232

# %%
scores = cross_val_score(forest_model, X_train, y_train, scoring="neg_mean_squared_error", cv=10)
rmse_validation = np.sqrt(-scores)

print("Scores: ", scores)
print("Mean: ", scores.mean())
print("Standard Deviation: ", scores.std())
# Out:
# Scores:  [-2.86283409e+09 -2.43024853e+09 -2.23867969e+09 -2.76113340e+09
#  -2.32465026e+09 -2.78226213e+09 -2.91975378e+09 -2.58001749e+09
#  -2.42289092e+09 -2.94717162e+09]
# Mean:  -2626964191.55453
# Standard Deviation:  247126988.12234282
